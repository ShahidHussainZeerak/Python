# %%
import pandas as pd

# %%
movies_data=pd.read_csv("tmdb_5000_movies.csv")
movies_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies_data[0:1] # slecting single row
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies_data[1:7] # selecting multiple rows.
# Out:
#    movie_id                                     title  \
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
#
#                                                 cast  \
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
# 5  [{"cast_id": 30, "character": "Peter Parker / ...
# 6  [{"cast_id": 34, "character": "Flynn Rider (vo...
#
#                                                 crew
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# ...

# %%
type(movies_data[1:7])
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
# ILOC ->rows selction through index base location... better and recomended method for rows slection.

# %%
movies_data.iloc[0]  # slect only one row.
# Out:
# movie_id                                                19995
# title                                                  Avatar
# cast        [{"cast_id": 242, "character": "Jake Sully", "...
# crew        [{"credit_id": "52fe48009251416c750aca23", "de...
# Name: 0, dtype: object

# %%
movies_data.iloc[0:10] #slecting multiple rows only.
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
# 8       767    Harry Potter and the Half-Blood Prince
# 9    209112        Batman v Superman: Dawn of Justice
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
# ...

# %%
movies_data.iloc[[0,3,6,7]]
# Out:
#    movie_id                    title  \
# 0     19995                   Avatar
# 3     49026    The Dark Knight Rises
# 6     38757                  Tangled
# 7     99861  Avengers: Age of Ultron
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 6  [{"cast_id": 34, "character": "Flynn Rider (vo...
# 7  [{"cast_id": 76, "character": "Tony Stark / Ir...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 6  [{"credit_id": "52fe46db9251416c91062101", "de...
# 7  [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...

# %%
movies_data.iloc[[0,2,3,4],[1,2,3]] # slectiong multiple individullay rows and columns  through slicing method
# Out:
#                    title                                               cast  \
# 0                 Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
# 2                Spectre  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  The Dark Knight Rises  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4            John Carter  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies_data.iloc[[0,2,3,4],0:5]# slectiong multiple rows and columns collectivelly through slicing method.
# Out:
#    movie_id                  title  \
# 0     19995                 Avatar
# 2    206647                Spectre
# 3     49026  The Dark Knight Rises
# 4     49529            John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
# LOC --> location base indexing same like ILOC but here we can pass name of rows insted of using index of that row.

# %%
movies_data=pd.read_csv("tmdb_5000_movies.csv",index_col ="title")#index_columns is used to give name to columns insted of using numbers.
movies_data.head()
# Out:
#                                           movie_id  \
# title
# Avatar                                       19995
# Pirates of the Caribbean: At World's End       285
# Spectre                                     206647
# The Dark Knight Rises                        49026
# John Carter                                  49529
#
#                                                                                        cast  \
# title
# Avatar                                    [{"cast_id": 242, "character": "Jake Sully", "...
# Pirates of the Caribbean: At World's End  [{"cast_id": 4, "character": "Captain Jack Spa...
# Spectre                                   [{"cast_id": 1, "character": "James Bond", "cr...
# The Dark Knight Rises                     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# John Carter                               [{"cast_id": 5, "character": "John Carter", "c...
#
# ...

# %%
  movies_data.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
movies_data.loc[0]
# Out:
# movie_id                                                19995
# title                                                  Avatar
# cast        [{"cast_id": 242, "character": "Jake Sully", "...
# crew        [{"credit_id": "52fe48009251416c750aca23", "de...
# Name: 0, dtype: object

# %%
movies_data.loc[0:3]
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...

# %%
movies_data.head()
# Out:
#                                           movie_id  \
# title
# Avatar                                       19995
# Pirates of the Caribbean: At World's End       285
# Spectre                                     206647
# The Dark Knight Rises                        49026
# John Carter                                  49529
#
#                                                                                        cast  \
# title
# Avatar                                    [{"cast_id": 242, "character": "Jake Sully", "...
# Pirates of the Caribbean: At World's End  [{"cast_id": 4, "character": "Captain Jack Spa...
# Spectre                                   [{"cast_id": 1, "character": "James Bond", "cr...
# The Dark Knight Rises                     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# John Carter                               [{"cast_id": 5, "character": "John Carter", "c...
#
# ...

# %%
movies_data.loc['Avatar'] # slecting single rows  by passing its original name .
# Out:
# movie_id                                                19995
# cast        [{"cast_id": 242, "character": "Jake Sully", "...
# crew        [{"credit_id": "52fe48009251416c750aca23", "de...
# Name: Avatar, dtype: object

# %%
movies_data.loc[['Avatar','Spectre','John Carter']] # slecting  multiple  rows  by passing its original name
# Out:
#              movie_id                                               cast  \
# title
# Avatar          19995  [{"cast_id": 242, "character": "Jake Sully", "...
# Spectre        206647  [{"cast_id": 1, "character": "James Bond", "cr...
# John Carter     49529  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                           crew
# title
# Avatar       [{"credit_id": "52fe48009251416c750aca23", "de...
# Spectre      [{"credit_id": "54805967c3a36829b5002c41", "de...
# John Carter  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies_data.loc[['Avatar','Spectre','John Carter'],['cast','crew']] # slecting rows and columns by passing its original name.
# Out:
#                                                           cast  \
# title
# Avatar       [{"cast_id": 242, "character": "Jake Sully", "...
# Spectre      [{"cast_id": 1, "character": "James Bond", "cr...
# John Carter  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                           crew
# title
# Avatar       [{"credit_id": "52fe48009251416c750aca23", "de...
# Spectre      [{"credit_id": "54805967c3a36829b5002c41", "de...
# John Carter  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
