# %%
import pandas as pd

# %%
data_19=pd.read_csv("2019.csv")

# %%
data_19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
data_19.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
data_19.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
data_19.columns.size
# Out:
# 8

# %%
data_19.index
# Out:
# Index(['Finland', 'Denmark', 'Norway', 'Iceland', 'Netherlands', 'Switzerland',
#        'Sweden', 'New Zealand', 'Canada', 'Austria',
#        ...
#        'Haiti', 'Botswana', 'Syria', 'Malawi', 'Yemen', 'Rwanda', 'Tanzania',
#        'Afghanistan', 'Central African Republic', 'South Sudan'],
#       dtype='object', name='Country or region', length=156)

# %%
data_19.shape
# Out:
# (156, 9)

# %%
data_19.loc[0:]
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
data_19.info() # meta information.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
data_19.iloc[4:10] #print country name from index 5 to 10
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Netherlands                   5  7.488           1.396           1.522
# Switzerland                   6  7.480           1.452           1.526
# Sweden                        7  7.343           1.387           1.487
# New Zealand                   8  7.307           1.303           1.557
# Canada                        9  7.278           1.365           1.505
# Austria                      10  7.246           1.376           1.475
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Netherlands                          0.999                         0.557
# Switzerland                          1.052                         0.572
# Sweden                               1.009                         0.574
# New Zealand                          1.026                         0.585
# ...

# %%
data_19=pd.read_csv("2019.csv" , index_col="Country or region") 
data_19.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                       1  7.769           1.340           1.587
# Denmark                       2  7.600           1.383           1.573
# Norway                        3  7.554           1.488           1.582
# Iceland                       4  7.494           1.380           1.624
# Netherlands                   5  7.488           1.396           1.522
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Finland                              0.986                         0.596
# Denmark                              0.996                         0.592
# Norway                               1.028                         0.603
# Iceland                              1.026                         0.591
# Netherlands                          0.999                         0.557
#
#                    Generosity  Perceptions of corruption
# ...

# %%
data_19.loc[['Japan','Pakistan','India'], 'Overall rank'] # to print rank of these countries.Overall ranlk to print in a cloumn.
# Out:
# Country or region
# Japan        58
# Pakistan     67
# India       140
# Name: Overall rank, dtype: int64
