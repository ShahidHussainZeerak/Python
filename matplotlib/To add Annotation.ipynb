# %%
import matplotlib.pyplot  as plt

# %%
plt.plot([10,20,30,40,],marker="o")
plt.annotate("this is a program",(2,20),size="large",color="red")
# Out:
# Text(2, 20, 'this is a program')

# %%
# if we want to use different argument then we will use this method/syntax
#annotate(yes,xy,xytext,xycoords,textcoords,arrowpops,annotation_clip,**kwargs)

# %%
plt.plot([10,20,30,40],[10,20,30,40],marker="o")
plt.annotate("Note this Point",(30,20),(20,30),arrowprops={"arrowstyle":"->","color":"black"},color="red",size=20,annotation_clip=False)
# Out:
# Text(20, 30, 'Note this Point')
