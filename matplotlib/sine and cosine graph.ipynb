# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t=np.arange(0,4*np.pi,0.5)
plt.plot(t,np.sin(t),marker="+")
plt.plot(t,np.cos(t),marker="<")
plt.xlabel("angle")
plt.ylabel("sine and cos value ")
plt.legend(["A","B"])
plt.show()
