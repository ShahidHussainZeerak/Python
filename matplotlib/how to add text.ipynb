# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5],marker="o")
plt.xlabel("x-label")
plt.ylabel("y-label")
plt.title("My First plot")
plt.text(2,4,"Note",{"size":"large","color":"red"})
plt.show()
