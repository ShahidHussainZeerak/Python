# %%
import  matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5,6,7],marker="o")
plt.show()

# %%
#Example : 2
year=[1990,1994,1996,1998,1999,2000,2004,2006,2010,2014]
unemploy=[1,5,6,9,3,4,10,1,11,10]
plt.plot(year,unemploy,marker="o")
plt.xlabel("year")
plt.ylabel("unemployement")
plt.title("year vs unemployement")
plt.show()
